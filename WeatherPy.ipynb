# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

from datetime import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
#Number of cities in the list: 587
# Out:
# Number of cities in the list: 612

# %%
#units Metric or Imperial
units = "metric"
print("HELLO")
# Out:
# HELLO

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
    #city_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=" + units

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto natales
# Processing Record 2 of Set 1 | fale old settlement
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | grytviken
# Processing Record 5 of Set 1 | ribeira grande
# Processing Record 6 of Set 1 | drayton valley
# Processing Record 7 of Set 1 | hawaiian paradise park
# Processing Record 8 of Set 1 | ukwa
# Processing Record 9 of Set 1 | afaahiti
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | aasiaat
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | bilibino
# Processing Record 14 of Set 1 | southeast arcadia
# Processing Record 15 of Set 1 | lagoa
# Processing Record 16 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 17 of Set 1 | mabaruma
# Processing Record 18 of Set 1 | at taj
# Processing Record 19 of Set 1 | espargos
# City not found. Skipping...
# Processing Record 20 of Set 1 | chonchi
# Processing Record 21 of Set 1 | utrik
# Processing Record 22 of Set 1 | adamstown
# Processing Record 23 of Set 1 | peruibe
# Processing Record 24 of Set 1 | yamada
# Processing Record 25 of Set 1 | blackmans bay
# Processing Record 26 of Set 1 | la sarre
# Processing Record 27 of Set 1 | ouani
# Processing Record 28 of Set 1 | general jose de san martin
# Processing Record 29 of Set 1 | beyneu
# Processing Record 30 of Set 1 | marsh harbour
# Processing Record 31 of Set 1 | severo-yeniseyskiy
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | ust-nera
# Processing Record 34 of Set 1 | sofifi
# Processing Record 35 of Set 1 | san antonio de pale
# Processing Record 36 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 37 of Set 1 | tiksi
# Processing Record 38 of Set 1 | iqaluit
# Processing Record 39 of Set 1 | suoyarvi
# Processing Record 40 of Set 1 | waitangi
# Processing Record 41 of Set 1 | tokar
# Processing Record 42 of Set 1 | longyearbyen
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | zuni pueblo
# Processing Record 45 of Set 1 | codrington
# Processing Record 46 of Set 1 | gobabis
# Processing Record 47 of Set 1 | hithadhoo
# Processing Record 48 of Set 1 | thompson
# Processing Record 49 of Set 1 | harstad
# Processing Record 50 of Set 1 | klaksvik
# Processing Record 0 of Set 2 | cockburn town
# Processing Record 1 of Set 2 | ushuaia
# Processing Record 2 of Set 2 | lycksele
# Processing Record 3 of Set 2 | el calafate
# Processing Record 4 of Set 2 | antsiranana
# Processing Record 5 of Set 2 | dudinka
# Processing Record 6 of Set 2 | luancheng
# Processing Record 7 of Set 2 | mar del plata
# Processing Record 8 of Set 2 | princeville
# Processing Record 9 of Set 2 | manzini
# Processing Record 10 of Set 2 | kovdor
# Processing Record 11 of Set 2 | pyapon
# Processing Record 12 of Set 2 | ilulissat
# Processing Record 13 of Set 2 | isafjordur
# Processing Record 14 of Set 2 | st. john's
# Processing Record 15 of Set 2 | la passe
# Processing Record 16 of Set 2 | college
# Processing Record 17 of Set 2 | stanley
# Processing Record 18 of Set 2 | whitehorse
# Processing Record 19 of Set 2 | guayaramerin
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | saldanha
# Processing Record 22 of Set 2 | emirdag
# Processing Record 23 of Set 2 | saipan
# Processing Record 24 of Set 2 | avarua
# Processing Record 25 of Set 2 | georgetown
# Processing Record 26 of Set 2 | selfoss
# Processing Record 27 of Set 2 | xilin hot
# Processing Record 28 of Set 2 | knyaze-volkonskoye
# Processing Record 29 of Set 2 | bamboo flat
# Processing Record 30 of Set 2 | fort bragg
# Processing Record 31 of Set 2 | vilyuysk
# Processing Record 32 of Set 2 | baukau
# Processing Record 33 of Set 2 | ta`u
# Processing Record 34 of Set 2 | evanston
# Processing Record 35 of Set 2 | mount gambier
# Processing Record 36 of Set 2 | bethel
# Processing Record 37 of Set 2 | huayacocotla
# Processing Record 38 of Set 2 | polyarnyy
# Processing Record 39 of Set 2 | san luis de la loma
# Processing Record 40 of Set 2 | qaqortoq
# Processing Record 41 of Set 2 | borogontsy
# Processing Record 42 of Set 2 | hadibu
# Processing Record 43 of Set 2 | bhopal
# Processing Record 44 of Set 2 | port elizabeth
# Processing Record 45 of Set 2 | mount isa
# Processing Record 46 of Set 2 | anadyr
# Processing Record 47 of Set 2 | pankovka
# Processing Record 48 of Set 2 | seven pagodas
# Processing Record 49 of Set 2 | constantia
# Processing Record 0 of Set 3 | imgarr
# Processing Record 1 of Set 3 | papatowai
# Processing Record 2 of Set 3 | leh
# Processing Record 3 of Set 3 | tralee
# Processing Record 4 of Set 3 | okhotsk
# Processing Record 5 of Set 3 | loa janan
# Processing Record 6 of Set 3 | coyhaique
# Processing Record 7 of Set 3 | nantucket
# Processing Record 8 of Set 3 | tura
# Processing Record 9 of Set 3 | kargasok
# Processing Record 10 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 11 of Set 3 | ubari
# Processing Record 12 of Set 3 | hamilton
# Processing Record 13 of Set 3 | devinuwara
# City not found. Skipping...
# Processing Record 14 of Set 3 | klyuchi
# Processing Record 15 of Set 3 | kununurra
# Processing Record 16 of Set 3 | sao desiderio
# Processing Record 17 of Set 3 | rikaze
# Processing Record 18 of Set 3 | eydhafushi
# Processing Record 19 of Set 3 | talnakh
# Processing Record 20 of Set 3 | castillos
# Processing Record 21 of Set 3 | tual
# Processing Record 22 of Set 3 | kodiak
# Processing Record 23 of Set 3 | kirovsk
# Processing Record 24 of Set 3 | beira
# Processing Record 25 of Set 3 | west island
# Processing Record 26 of Set 3 | kapa'a
# Processing Record 27 of Set 3 | byron bay
# Processing Record 28 of Set 3 | dolores
# Processing Record 29 of Set 3 | uliastay
# Processing Record 30 of Set 3 | banda aceh
# Processing Record 31 of Set 3 | torata
# Processing Record 32 of Set 3 | eyl
# Processing Record 33 of Set 3 | vorgashor
# Processing Record 34 of Set 3 | djambala
# Processing Record 35 of Set 3 | mariental
# Processing Record 36 of Set 3 | flying fish cove
# Processing Record 37 of Set 3 | mata-utu
# Processing Record 38 of Set 3 | atafu village
# Processing Record 39 of Set 3 | invercargill
# Processing Record 40 of Set 3 | tranovaho
# City not found. Skipping...
# Processing Record 41 of Set 3 | bratsk
# Processing Record 42 of Set 3 | altai
# Processing Record 43 of Set 3 | port saint john's
# Processing Record 44 of Set 3 | kingston
# Processing Record 45 of Set 3 | codo
# Processing Record 46 of Set 3 | kruisfontein
# Processing Record 47 of Set 3 | olonkinbyen
# Processing Record 48 of Set 3 | la ronge
# Processing Record 49 of Set 3 | chu
# Processing Record 0 of Set 4 | nadi
# Processing Record 1 of Set 4 | grantsville
# Processing Record 2 of Set 4 | lihue
# Processing Record 3 of Set 4 | kloulklubed
# Processing Record 4 of Set 4 | carnarvon
# Processing Record 5 of Set 4 | kalabo
# Processing Record 6 of Set 4 | pabna
# Processing Record 7 of Set 4 | edinburgh of the seven seas
# Processing Record 8 of Set 4 | sal rei
# Processing Record 9 of Set 4 | madalena
# Processing Record 10 of Set 4 | pandan
# Processing Record 11 of Set 4 | cadale
# Processing Record 12 of Set 4 | kailua-kona
# Processing Record 13 of Set 4 | yellowknife
# Processing Record 14 of Set 4 | suva
# Processing Record 15 of Set 4 | akdepe
# Processing Record 16 of Set 4 | lerwick
# Processing Record 17 of Set 4 | hotan
# Processing Record 18 of Set 4 | badger
# Processing Record 19 of Set 4 | piti village
# Processing Record 20 of Set 4 | coquimbo
# Processing Record 21 of Set 4 | margate
# Processing Record 22 of Set 4 | ambon
# Processing Record 23 of Set 4 | turpan
# Processing Record 24 of Set 4 | karratha
# Processing Record 25 of Set 4 | turochak
# Processing Record 26 of Set 4 | kuraymah
# Processing Record 27 of Set 4 | krivosheino
# Processing Record 28 of Set 4 | whyalla stuart
# City not found. Skipping...
# Processing Record 29 of Set 4 | brazzaville
# Processing Record 30 of Set 4 | palmer
# Processing Record 31 of Set 4 | chabahar
# Processing Record 32 of Set 4 | lishu
# Processing Record 33 of Set 4 | margaret river
# Processing Record 34 of Set 4 | shiguai
# Processing Record 35 of Set 4 | usinsk
# Processing Record 36 of Set 4 | mawu
# Processing Record 37 of Set 4 | birao
# Processing Record 38 of Set 4 | lebu
# Processing Record 39 of Set 4 | toliara
# Processing Record 40 of Set 4 | fendou
# Processing Record 41 of Set 4 | san juan de miraflores
# Processing Record 42 of Set 4 | namibe
# Processing Record 43 of Set 4 | prieska
# Processing Record 44 of Set 4 | dwarka
# Processing Record 45 of Set 4 | cidreira
# Processing Record 46 of Set 4 | arraial do cabo
# Processing Record 47 of Set 4 | tarauaca
# Processing Record 48 of Set 4 | saint-philippe
# Processing Record 49 of Set 4 | bac lieu
# Processing Record 0 of Set 5 | vila franca do campo
# Processing Record 1 of Set 5 | hermanus
# Processing Record 2 of Set 5 | miles city
# Processing Record 3 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 4 of Set 5 | mao
# Processing Record 5 of Set 5 | new norfolk
# Processing Record 6 of Set 5 | beardstown
# Processing Record 7 of Set 5 | ola
# Processing Record 8 of Set 5 | wailua homesteads
# Processing Record 9 of Set 5 | sinabang
# Processing Record 10 of Set 5 | zhezqazghan
# Processing Record 11 of Set 5 | sitka
# Processing Record 12 of Set 5 | ad dabbah
# Processing Record 13 of Set 5 | iskateley
# Processing Record 14 of Set 5 | saint-joseph
# Processing Record 15 of Set 5 | desnogorsk
# Processing Record 16 of Set 5 | box elder
# Processing Record 17 of Set 5 | papao
# Processing Record 18 of Set 5 | kristiansund
# Processing Record 19 of Set 5 | zhongshu
# Processing Record 20 of Set 5 | dunedin
# Processing Record 21 of Set 5 | turtas
# Processing Record 22 of Set 5 | nuuk
# Processing Record 23 of Set 5 | bayan nur
# City not found. Skipping...
# Processing Record 24 of Set 5 | hun
# Processing Record 25 of Set 5 | russkaya polyana
# Processing Record 26 of Set 5 | qeshm
# Processing Record 27 of Set 5 | palikir - national government center
# Processing Record 28 of Set 5 | cabedelo
# Processing Record 29 of Set 5 | uturoa
# Processing Record 30 of Set 5 | anna regina
# Processing Record 31 of Set 5 | la palma
# Processing Record 32 of Set 5 | saudarkrokur
# Processing Record 33 of Set 5 | kodinsk
# Processing Record 34 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 35 of Set 5 | morondava
# Processing Record 36 of Set 5 | mek'ele
# Processing Record 37 of Set 5 | wangqing
# Processing Record 38 of Set 5 | kosciuszko national park
# City not found. Skipping...
# Processing Record 39 of Set 5 | sovetskiy
# Processing Record 40 of Set 5 | christchurch
# Processing Record 41 of Set 5 | tumayr
# Processing Record 42 of Set 5 | chernyshevskiy
# Processing Record 43 of Set 5 | hasaki
# Processing Record 44 of Set 5 | east london
# Processing Record 45 of Set 5 | udachny
# Processing Record 46 of Set 5 | dausa
# Processing Record 47 of Set 5 | port lincoln
# Processing Record 48 of Set 5 | port mathurin
# Processing Record 49 of Set 5 | khandyga
# Processing Record 0 of Set 6 | nuku'alofa
# Processing Record 1 of Set 6 | yeosu
# Processing Record 2 of Set 6 | zaporizhia
# Processing Record 3 of Set 6 | queenstown
# Processing Record 4 of Set 6 | cheongsong gun
# Processing Record 5 of Set 6 | oban
# Processing Record 6 of Set 6 | guiria
# City not found. Skipping...
# Processing Record 7 of Set 6 | maun
# Processing Record 8 of Set 6 | n'djamena
# Processing Record 9 of Set 6 | neryungri
# Processing Record 10 of Set 6 | laibin
# Processing Record 11 of Set 6 | zangguy
# City not found. Skipping...
# Processing Record 12 of Set 6 | ban tak
# Processing Record 13 of Set 6 | nizhnesortymskiy
# Processing Record 14 of Set 6 | stephenville
# Processing Record 15 of Set 6 | dar naim
# City not found. Skipping...
# Processing Record 16 of Set 6 | illizi
# Processing Record 17 of Set 6 | ulladulla
# Processing Record 18 of Set 6 | belyy yar
# Processing Record 19 of Set 6 | nova sintra
# Processing Record 20 of Set 6 | mil'kovo
# Processing Record 21 of Set 6 | chilecito
# Processing Record 22 of Set 6 | anloga
# Processing Record 23 of Set 6 | kamina
# Processing Record 24 of Set 6 | baharly
# Processing Record 25 of Set 6 | broken hill
# Processing Record 26 of Set 6 | undurkhaan
# Processing Record 27 of Set 6 | north side
# Processing Record 28 of Set 6 | bealanana
# Processing Record 29 of Set 6 | cabo san lucas
# Processing Record 30 of Set 6 | akureyri
# Processing Record 31 of Set 6 | hancheng
# Processing Record 32 of Set 6 | cauto cristo
# Processing Record 33 of Set 6 | sao felix do xingu
# Processing Record 34 of Set 6 | serowe
# Processing Record 35 of Set 6 | nikolayevsk-on-amure
# Processing Record 36 of Set 6 | labytnangi
# Processing Record 37 of Set 6 | sirsilla
# Processing Record 38 of Set 6 | barcelos
# Processing Record 39 of Set 6 | krasnoshchekovo
# Processing Record 40 of Set 6 | gorontalo
# Processing Record 41 of Set 6 | cairns city
# City not found. Skipping...
# Processing Record 42 of Set 6 | sodra sandby
# Processing Record 43 of Set 6 | uromi
# Processing Record 44 of Set 6 | rio gallegos
# Processing Record 45 of Set 6 | weihai
# Processing Record 46 of Set 6 | enewetak
# Processing Record 47 of Set 6 | isangel
# Processing Record 48 of Set 6 | mananjary
# Processing Record 49 of Set 6 | howrah
# Processing Record 0 of Set 7 | zimovniki
# Processing Record 1 of Set 7 | antofagasta
# Processing Record 2 of Set 7 | zaozersk
# Processing Record 3 of Set 7 | tazovsky
# Processing Record 4 of Set 7 | auna
# Processing Record 5 of Set 7 | bocana de paiwas
# Processing Record 6 of Set 7 | arroyito
# Processing Record 7 of Set 7 | nagqu
# Processing Record 8 of Set 7 | pallasovka
# Processing Record 9 of Set 7 | kinablangan
# Processing Record 10 of Set 7 | le coteau
# Processing Record 11 of Set 7 | koulamoutou
# Processing Record 12 of Set 7 | kargat
# Processing Record 13 of Set 7 | la'ie
# Processing Record 14 of Set 7 | syumsi
# Processing Record 15 of Set 7 | punta arenas
# Processing Record 16 of Set 7 | le port
# Processing Record 17 of Set 7 | rabigh
# Processing Record 18 of Set 7 | san jose village
# City not found. Skipping...
# Processing Record 19 of Set 7 | enriquillo
# Processing Record 20 of Set 7 | singkil
# Processing Record 21 of Set 7 | lokomotivnyy
# Processing Record 22 of Set 7 | nemuro
# Processing Record 23 of Set 7 | zalingei
# Processing Record 24 of Set 7 | sandnessjoen
# Processing Record 25 of Set 7 | cole harbour
# Processing Record 26 of Set 7 | susuman
# Processing Record 27 of Set 7 | fort st. john
# Processing Record 28 of Set 7 | manado
# Processing Record 29 of Set 7 | cidade velha
# Processing Record 30 of Set 7 | parabel'
# Processing Record 31 of Set 7 | rio turbio
# City not found. Skipping...
# Processing Record 32 of Set 7 | gutierrez zamora
# Processing Record 33 of Set 7 | asau village
# City not found. Skipping...
# Processing Record 34 of Set 7 | manicore
# Processing Record 35 of Set 7 | vadso
# Processing Record 36 of Set 7 | sharkawshchyna
# Processing Record 37 of Set 7 | portland
# Processing Record 38 of Set 7 | ghanzi
# Processing Record 39 of Set 7 | buka
# Processing Record 40 of Set 7 | inhambane
# Processing Record 41 of Set 7 | mejit
# Processing Record 42 of Set 7 | san patricio
# Processing Record 43 of Set 7 | klintsy
# Processing Record 44 of Set 7 | yeppoon
# Processing Record 45 of Set 7 | tromso
# Processing Record 46 of Set 7 | 'ohonua
# City not found. Skipping...
# Processing Record 47 of Set 7 | murovani kurylivtsi
# Processing Record 48 of Set 7 | robertsport
# Processing Record 49 of Set 7 | zhaqsy
# Processing Record 0 of Set 8 | la rinconada
# Processing Record 1 of Set 8 | lorengau
# Processing Record 2 of Set 8 | peace river
# Processing Record 3 of Set 8 | laguna
# Processing Record 4 of Set 8 | yuzhno-kurilsk
# Processing Record 5 of Set 8 | port-vila
# Processing Record 6 of Set 8 | kourou
# Processing Record 7 of Set 8 | myitkyina
# Processing Record 8 of Set 8 | natal
# Processing Record 9 of Set 8 | mournies
# Processing Record 10 of Set 8 | qamdo
# Processing Record 11 of Set 8 | bayji
# Processing Record 12 of Set 8 | boguchany
# Processing Record 13 of Set 8 | mafraq
# Processing Record 14 of Set 8 | luderitz
# Processing Record 15 of Set 8 | weno
# Processing Record 16 of Set 8 | great falls
# Processing Record 17 of Set 8 | wenchang
# Processing Record 18 of Set 8 | uruzgan
# Processing Record 19 of Set 8 | kulia village
# City not found. Skipping...
# Processing Record 20 of Set 8 | lata
# Processing Record 21 of Set 8 | geraldton
# Processing Record 22 of Set 8 | mushie
# Processing Record 23 of Set 8 | ulsteinvik
# Processing Record 24 of Set 8 | pahrump
# Processing Record 25 of Set 8 | cartagena
# Processing Record 26 of Set 8 | vilyuchinsk
# Processing Record 27 of Set 8 | edson
# Processing Record 28 of Set 8 | fortuna
# Processing Record 29 of Set 8 | kerikeri
# Processing Record 30 of Set 8 | broome
# Processing Record 31 of Set 8 | keflavik
# Processing Record 32 of Set 8 | bilao
# Processing Record 33 of Set 8 | vila do maio
# Processing Record 34 of Set 8 | ciudad cuauhtemoc
# Processing Record 35 of Set 8 | la gi
# Processing Record 36 of Set 8 | north bend
# Processing Record 37 of Set 8 | tateyama
# Processing Record 38 of Set 8 | nouadhibou
# Processing Record 39 of Set 8 | enumclaw
# Processing Record 40 of Set 8 | cocal
# Processing Record 41 of Set 8 | prado
# Processing Record 42 of Set 8 | puerto aysen
# Processing Record 43 of Set 8 | egilsstadir
# Processing Record 44 of Set 8 | jiwani
# Processing Record 45 of Set 8 | chimoio
# Processing Record 46 of Set 8 | hammerfest
# Processing Record 47 of Set 8 | alamosa
# Processing Record 48 of Set 8 | alaghsas
# Processing Record 49 of Set 8 | chipata
# Processing Record 0 of Set 9 | zhaobaoshan
# Processing Record 1 of Set 9 | siwa oasis
# Processing Record 2 of Set 9 | ad-damazin
# Processing Record 3 of Set 9 | tercan
# Processing Record 4 of Set 9 | nyrob
# Processing Record 5 of Set 9 | ghadamis
# Processing Record 6 of Set 9 | remire-montjoly
# Processing Record 7 of Set 9 | huilong
# Processing Record 8 of Set 9 | ancud
# Processing Record 9 of Set 9 | tinajo
# Processing Record 10 of Set 9 | jayapura
# Processing Record 11 of Set 9 | ghat
# Processing Record 12 of Set 9 | taoudenni
# Processing Record 13 of Set 9 | holualoa
# Processing Record 14 of Set 9 | komsomolsk-on-amur
# Processing Record 15 of Set 9 | hede
# Processing Record 16 of Set 9 | jiazi
# Processing Record 17 of Set 9 | belmonte
# Processing Record 18 of Set 9 | trairi
# Processing Record 19 of Set 9 | kavaratti
# Processing Record 20 of Set 9 | campo maior
# Processing Record 21 of Set 9 | galesong
# Processing Record 22 of Set 9 | minas de marcona
# Processing Record 23 of Set 9 | santana
# Processing Record 24 of Set 9 | ouesso
# Processing Record 25 of Set 9 | chernyshevsk
# Processing Record 26 of Set 9 | pyrgos
# Processing Record 27 of Set 9 | zindah jan
# Processing Record 28 of Set 9 | chavusy
# Processing Record 29 of Set 9 | espoo
# Processing Record 30 of Set 9 | stornoway
# Processing Record 31 of Set 9 | sao joao da barra
# Processing Record 32 of Set 9 | rio grande
# Processing Record 33 of Set 9 | songling
# Processing Record 34 of Set 9 | bismarck
# Processing Record 35 of Set 9 | santa vitoria do palmar
# Processing Record 36 of Set 9 | guiglo
# Processing Record 37 of Set 9 | griffith
# Processing Record 38 of Set 9 | meraux
# Processing Record 39 of Set 9 | palu
# Processing Record 40 of Set 9 | ban dung
# Processing Record 41 of Set 9 | midvagur
# Processing Record 42 of Set 9 | chibougamau
# Processing Record 43 of Set 9 | tamanrasset
# Processing Record 44 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 45 of Set 9 | sotouboua
# Processing Record 46 of Set 9 | ebon
# Processing Record 47 of Set 9 | chadan
# Processing Record 48 of Set 9 | tymovskoye
# Processing Record 49 of Set 9 | malabar
# Processing Record 0 of Set 10 | santiago
# Processing Record 1 of Set 10 | yelizovo
# Processing Record 2 of Set 10 | lompoc
# Processing Record 3 of Set 10 | nar'yan-mar
# Processing Record 4 of Set 10 | okha
# Processing Record 5 of Set 10 | uyuni
# Processing Record 6 of Set 10 | tadine
# Processing Record 7 of Set 10 | grand falls-windsor
# Processing Record 8 of Set 10 | cill airne
# Processing Record 9 of Set 10 | volodarskiy
# Processing Record 10 of Set 10 | cannonvale
# Processing Record 11 of Set 10 | bria
# Processing Record 12 of Set 10 | cargados carajos
# City not found. Skipping...
# Processing Record 13 of Set 10 | sinop
# Processing Record 14 of Set 10 | cooma
# Processing Record 15 of Set 10 | zhengjiatun
# Processing Record 16 of Set 10 | romanovskaya
# Processing Record 17 of Set 10 | korla
# Processing Record 18 of Set 10 | galeana
# Processing Record 19 of Set 10 | juan griego
# Processing Record 20 of Set 10 | kirensk
# Processing Record 21 of Set 10 | puerto madero
# Processing Record 22 of Set 10 | arkalyk
# Processing Record 23 of Set 10 | lhokseumawe
# Processing Record 24 of Set 10 | newman
# Processing Record 25 of Set 10 | jiangyou
# Processing Record 26 of Set 10 | tyukhtet
# Processing Record 27 of Set 10 | ialibu
# Processing Record 28 of Set 10 | boende
# Processing Record 29 of Set 10 | kavieng
# Processing Record 30 of Set 10 | bardai
# Processing Record 31 of Set 10 | murgab
# Processing Record 32 of Set 10 | mount pearl
# Processing Record 33 of Set 10 | scarborough
# Processing Record 34 of Set 10 | timbuktu
# Processing Record 35 of Set 10 | thurso
# Processing Record 36 of Set 10 | dom pedrito
# Processing Record 37 of Set 10 | puerto deseado
# Processing Record 38 of Set 10 | farah
# Processing Record 39 of Set 10 | zouerate
# Processing Record 40 of Set 10 | vangaindrano
# Processing Record 41 of Set 10 | oranjemund
# Processing Record 42 of Set 10 | alotau
# Processing Record 43 of Set 10 | bel ombre
# Processing Record 44 of Set 10 | merizo village
# Processing Record 45 of Set 10 | al jawf
# Processing Record 46 of Set 10 | placido de castro
# Processing Record 47 of Set 10 | rumphi
# Processing Record 48 of Set 10 | tolanaro
# Processing Record 49 of Set 10 | biala podlaska
# Processing Record 0 of Set 11 | faya-largeau
# Processing Record 1 of Set 11 | nogliki
# Processing Record 2 of Set 11 | dzhalagash
# Processing Record 3 of Set 11 | qarqaraly
# Processing Record 4 of Set 11 | lukolela
# Processing Record 5 of Set 11 | nanpiao
# Processing Record 6 of Set 11 | kalanaur
# Processing Record 7 of Set 11 | huocheng
# City not found. Skipping...
# Processing Record 8 of Set 11 | sittwe
# Processing Record 9 of Set 11 | imbituba
# Processing Record 10 of Set 11 | arauco
# Processing Record 11 of Set 11 | antalaha
# Processing Record 12 of Set 11 | itacarambi
# Processing Record 13 of Set 11 | gadani
# Processing Record 14 of Set 11 | brisas de zicatela
# Processing Record 15 of Set 11 | morrope
# Processing Record 16 of Set 11 | goure
# Processing Record 17 of Set 11 | kismayo
# Processing Record 18 of Set 11 | mbandjok
# Processing Record 19 of Set 11 | tutoia
# Processing Record 20 of Set 11 | alofi
# Processing Record 21 of Set 11 | sydney
# Processing Record 22 of Set 11 | long xuyen
# Processing Record 23 of Set 11 | dakhla
# Processing Record 24 of Set 11 | viedma
# Processing Record 25 of Set 11 | wewak
# Processing Record 26 of Set 11 | solnechnyy
# Processing Record 27 of Set 11 | mpika
# Processing Record 28 of Set 11 | raja
# Processing Record 29 of Set 11 | kayangel
# Processing Record 30 of Set 11 | amarpatan
# Processing Record 31 of Set 11 | buriti bravo
# Processing Record 32 of Set 11 | mersing
# Processing Record 33 of Set 11 | baidoa
# Processing Record 34 of Set 11 | taroa
# Processing Record 35 of Set 11 | laojunmiao
# Processing Record 36 of Set 11 | verkhnevilyuysk
# Processing Record 37 of Set 11 | patterson
# Processing Record 38 of Set 11 | praia da vitoria
# Processing Record 39 of Set 11 | kasongo-lunda
# Processing Record 40 of Set 11 | ahau
# City not found. Skipping...
# Processing Record 41 of Set 11 | zalari
# Processing Record 42 of Set 11 | novodvinsk
# Processing Record 43 of Set 11 | vernon
# Processing Record 44 of Set 11 | mikhaylovskoye
# Processing Record 45 of Set 11 | ivanava
# Processing Record 46 of Set 11 | mostaganem
# Processing Record 47 of Set 11 | bejubang dua
# City not found. Skipping...
# Processing Record 48 of Set 11 | hobyo
# Processing Record 49 of Set 11 | tazacorte
# Processing Record 0 of Set 12 | okahandja
# Processing Record 1 of Set 12 | naze
# Processing Record 2 of Set 12 | vallenar
# Processing Record 3 of Set 12 | oruro
# Processing Record 4 of Set 12 | shohimardon
# Processing Record 5 of Set 12 | fujin
# Processing Record 6 of Set 12 | east ballina
# Processing Record 7 of Set 12 | ust'-ilimsk
# Processing Record 8 of Set 12 | farrukhnagar
# Processing Record 9 of Set 12 | donetsk
# Processing Record 10 of Set 12 | bada
# Processing Record 11 of Set 12 | campobello di mazara
# Processing Record 12 of Set 12 | tevriz
# Processing Record 13 of Set 12 | pudasjarvi
# Processing Record 14 of Set 12 | jose mariano jimenez
# City not found. Skipping...
# Processing Record 15 of Set 12 | manavalakurichi
# Processing Record 16 of Set 12 | harriman
# Processing Record 17 of Set 12 | whakatane
# Processing Record 18 of Set 12 | pekan
# Processing Record 19 of Set 12 | dzuunmod
# Processing Record 20 of Set 12 | souillac
# Processing Record 21 of Set 12 | mostar
# Processing Record 22 of Set 12 | tommot
# Processing Record 23 of Set 12 | diplo
# Processing Record 24 of Set 12 | yashkul'
# Processing Record 25 of Set 12 | preobrazheniye
# Processing Record 26 of Set 12 | bahia de caraquez
# Processing Record 27 of Set 12 | mazatlan
# Processing Record 28 of Set 12 | arenal
# Processing Record 29 of Set 12 | greenville
# Processing Record 30 of Set 12 | takoradi
# Processing Record 31 of Set 12 | bonthe
# Processing Record 32 of Set 12 | colonia
# Processing Record 33 of Set 12 | muisne
# Processing Record 34 of Set 12 | bouarfa
# Processing Record 35 of Set 12 | port moresby
# Processing Record 36 of Set 12 | kimbe
# Processing Record 37 of Set 12 | djebeniana
# Processing Record 38 of Set 12 | yaren
# Processing Record 39 of Set 12 | alice springs
# Processing Record 40 of Set 12 | sonsorol village
# City not found. Skipping...
# Processing Record 41 of Set 12 | ust'-uda
# Processing Record 42 of Set 12 | pechora
# Processing Record 43 of Set 12 | santa cruz
# Processing Record 44 of Set 12 | ustka
# Processing Record 45 of Set 12 | forster
# Processing Record 46 of Set 12 | sao paulo de olivenca
# Processing Record 47 of Set 12 | gorom-gorom
# Processing Record 48 of Set 12 | arkhara
# Processing Record 49 of Set 12 | i-n-salah
# Processing Record 0 of Set 13 | acoyapa
# Processing Record 1 of Set 13 | biltine
# Processing Record 2 of Set 13 | kiunga
# Processing Record 3 of Set 13 | kashgar
# Processing Record 4 of Set 13 | lensk
# Processing Record 5 of Set 13 | lethem
# Processing Record 6 of Set 13 | salaqi
# Processing Record 7 of Set 13 | tofol
# Processing Record 8 of Set 13 | traralgon
# Processing Record 9 of Set 13 | mukalla
# Processing Record 10 of Set 13 | labasa
# Processing Record 11 of Set 13 | vilhena
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame.from_dict(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          586
# Lat           586
# Lng           586
# Max Temp      586
# Humidity      586
# Cloudiness    586
# Wind Speed    586
# Country       586
# Date          586
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       puerto natales -51.7236  -72.4875      8.25        57          75
# 1  fale old settlement  -9.3852 -171.2468     28.10        78          18
# 2    port-aux-francais -49.3500   70.2167      3.39        69           7
# 3            grytviken -54.2811  -36.5092     -1.56        97         100
# 4       ribeira grande  38.5167  -28.7000     24.87        83          75
#
#    Wind Speed Country        Date
# 0       11.83      CL  1721675996
# 1       10.58      TK  1721675998
# 2        8.91      TF  1721675999
# 3        1.79      GS  1721676000
# 4        2.06      PT  1721676001

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0             puerto natales -51.7236  -72.4875      8.25        57
# 1        fale old settlement  -9.3852 -171.2468     28.10        78
# 2          port-aux-francais -49.3500   70.2167      3.39        69
# 3                  grytviken -54.2811  -36.5092     -1.56        97
# 4             ribeira grande  38.5167  -28.7000     24.87        83
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                75       11.83      CL  1721675996
# 1                18       10.58      TK  1721675998
# 2                 7        8.91      TF  1721675999
# 3               100        1.79      GS  1721676000
# 4                75        2.06      PT  1721676001

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], alpha=.8, edgecolors="k")

#Date Format
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature (C)")
plt.title(f"City Latitude vs. Temperature ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (meters/sec)")
plt.title(f"City Latitude vs. Humidity ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
#(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#regress_values = x_values * slope + intercept
#line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemisphere_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) > 0, :]

# Display sample data
northern_hemisphere_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 4                ribeira grande  38.5167  -28.7000     24.87        83
# 5                drayton valley  53.2168 -114.9854     27.11        57
# 6        hawaiian paradise park  19.5933 -154.9731     27.24        74
# 7                          ukwa  21.9667   80.4667     23.66        99
# 10                      aasiaat  68.7098  -52.8699      3.09        92
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 4                75        2.06      PT  1721676001
# 5               100        6.48      CA  1721676003
# 6                40        3.09      US  1721676004
# 7                99        2.80      IN  1721676005
# 10               77        3.12      GL  1721676008

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemisphere_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) < 0, :]

# Display sample data
southern_hemisphere_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0             puerto natales -51.7236  -72.4875      8.25        57
# 1        fale old settlement  -9.3852 -171.2468     28.10        78
# 2          port-aux-francais -49.3500   70.2167      3.39        69
# 3                  grytviken -54.2811  -36.5092     -1.56        97
# 8                   afaahiti -17.7500 -149.2833     24.93        70
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                75       11.83      CL  1721675996
# 1                18       10.58      TK  1721675998
# 2                 7        8.91      TF  1721675999
# 3               100        1.79      GS  1721676000
# 8                88        9.19      PF  1721676006

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemisphere_df["Lat"]
y_values = northern_hemisphere_df["Max Temp"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(0,-20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
print("*"*70)
print("Observations about linear relationship:")
print("The regression displays a negative relationship between temperature and latitude")
print("In the northern hemisphere, as the latitude increases the temperature decreases.")
# Out:
# The r-value is -0.6301156844102036
# **********************************************************************
# Observations about linear relationship:
# The regression displays a negative relationship between temperature and latitude
# In the northern hemisphere, as the latitude increases the temperature decreases.

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemisphere_df["Lat"]
y_values = southern_hemisphere_df["Max Temp"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(0,-20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
print("*"*70)
print("Observations about linear relationship:")
print("The regression displays a positive relationship between temperature and latitude")
print("In the souther hemisphere, as the latitude increases the temperature decreases.")
# Out:
# The r-value is 0.7978028372087947
# **********************************************************************
# Observations about linear relationship:
# The regression displays a positive relationship between temperature and latitude
# In the souther hemisphere, as the latitude increases the temperature decreases.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
# Observations about linear relationship:
# The regression displays a positive relationship between temperature and latitude
# In the souther hemisphere, as the latitude increases the temperature decreases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere
x_values = northern_hemisphere_df["Lat"]
y_values = northern_hemisphere_df["Humidity"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is {rvalue}')
print("*"*120)
print("Observations about linear relationship:")
print("The relationship is slightly positive, though there doesn't appear to be a strong coorelation between humidity and latitude.")
# Out:
# The r-value is -0.01812639646000037
# ************************************************************************************************************************
# Observations about linear relationship:
# The relationship is slightly positive, though there doesn't appear to be a strong coorelation between humidity and latitude.

# %%
# Southern Hemisphere

x_values = southern_hemisphere_df["Lat"]
y_values = southern_hemisphere_df["Humidity"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-30,30),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is {rvalue}')
print("*"*40)
print("Observations about linear relationship:")
print("The relationship is slightly negative.")
print("Humidity decreases as altitude increases.")
# Out:
# The r-value is -0.11992940986523015
# ****************************************
# Observations about linear relationship:
# The relationship is slightly negative.
# Humidity decreases as altitude increases.

# %%
Observations about linear relationship:
The relationship is slightly negative.
Humidity decreases as altitude increases.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
# Observations about linear relationship:
# The relationship is slightly negative.
# Humidity decreases as altitude increases.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemisphere_df["Lat"]
y_values = northern_hemisphere_df["Cloudiness"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=20,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is {rvalue}')
print("*"*70)
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and cloudiness.")
# Out:
# The r-value is -0.032220778465293566
# **********************************************************************
# Observations about linear relationship:
# There does not appear to be a coorelation between latitude and cloudiness.

# %%
# Southern Hemisphere
x_values = southern_hemisphere_df["Lat"]
y_values = southern_hemisphere_df["Cloudiness"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is {rvalue}')
print("*"*70)
print("Observations about linear relationship:")
print("Cloudiness is not affected by latitude. It tends to be almost constant")
# Out:
# The r-value is 0.03762108314137102
# **********************************************************************
# Observations about linear relationship:
# Cloudiness is not affected by latitude. It tends to be almost constant

# %% [markdown]
# **Discussion about the linear relationship:**
# Cloudiness is not affected by latitude. It tends to be almost constant

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = southern_hemisphere_df["Lat"]
y_values = southern_hemisphere_df["Wind Speed"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is {rvalue}')
print("*"*70)
print("Observations about linear relationship:")
print("Wind Speed is not affected by latitude. It tends to be almost constant")
# Out:
# The r-value is -0.0666517758931965
# **********************************************************************
# Observations about linear relationship:
# Wind Speed is not affected by latitude. It tends to be almost constant

# %%
**Discussion about the linear relationship:** 
##Wind Speed is not affected by latitude. It tends to be almost constant

# %%
# Southern Hemisphere
x_values = southern_hemisphere_df["Lat"]
y_values = southern_hemisphere_df["Wind Speed"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is {rvalue}')
print("*"*70)
print("Observations about linear relationship:")
print("Wind Speed is not affected by latitude. It tends to be almost constant")
# Out:
# The r-value is -0.0666517758931965
# **********************************************************************
# Observations about linear relationship:
# Wind Speed is not affected by latitude. It tends to be almost constant

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
# Wind Speed is not affected by latitude. It tends to be almost constant
